# %% [markdown]
# <a href="https://colab.research.google.com/github/sh3986/kaggle/blob/main/v2_aug_gray_constast_shuffle_keras_resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Library

# %%
import numpy as np 
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
pd.options.display.float_format = "{:.5f}".format

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import Pipeline

import os
from os import listdir
from os.path import isfile, join
import cv2
from PIL import Image
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras import optimizers
tf.__version__
# Out:
# '2.8.2'

# %%
# Visualization
from tensorflow.keras.utils import plot_model

# Splitting data
from sklearn.model_selection import train_test_split

# Metrics 
from sklearn.metrics import confusion_matrix, classification_report

# Deep Learning
import tensorflow as tf
print('TensoFlow Version: ', tf.__version__)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications.resnet import ResNet50

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger

import skimage.morphology as morp
from skimage.filters import rank
# Out:
# TensoFlow Version:  2.8.2

# %%
data_path = "/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn"

# %%
import os
os.chdir(data_path)

# %%
data = []
labels = []

height = 32
width = 32
channels = 3
num_classes = 43

# %%
def img_contrast(img):
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    return final

# %%
# for i in range(num_classes) :
#     path = f'./data/Train/{i}/'
#     Class = os.listdir(path)
#     for a in Class:
#         image = cv2.imread(path + a)
#         image_from_array = Image.fromarray(image, 'RGB')
#         size_image = image_from_array.resize((height, width))
#         data.append(np.array(size_image))
#         labels.append(i)
        
#         image = img_contrast(image)
#         image_from_array = Image.fromarray(image, 'RGB')
#         size_image = image_from_array.resize((height, width))
#         data.append(np.array(size_image))
#         labels.append(i)

# data = np.array(data)
# labels = np.array(labels)

# import pickle
# with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_data_with_contrast.pkl","wb") as f:
#     pickle.dump(data, f)

# with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_label_with_contrast.pkl","wb") as f:
#     pickle.dump(labels, f)

# %% [markdown]
# ### 데이터 로드

# %%
import pickle
with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_data.pkl","rb") as f:
    data = pickle.load(f)

import pickle
with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_label.pkl","rb") as f:
    labels = pickle.load(f)

# %%
print(data.shape)
print(labels.shape)
# Out:
# (26010, 32, 32, 3)
# (26010,)

# %% [markdown]
# ### 탐색 분석

# %%
X = data
y = tf.one_hot(labels, num_classes).numpy()

# %%
fig, axes = plt.subplots(10,10, figsize=(18,18))
for i,ax in enumerate(axes.flat):
    r = np.random.randint(X.shape[0])
    ax.imshow(X[r].astype('uint8'))
    ax.grid(False)
    ax.axis('off')
    ax.set_title('Label: '+str(np.argmax(y[r]))+" "+str(r))

# %%
f, ax = plt.subplots(figsize=(10, 5))
sns.countplot(labels)

# %%
uni_pattern = np.unique(labels, return_counts=True)
idxs = uni_pattern[0]
ratios = uni_pattern[1]/len(labels)

# %% [markdown]
# ### 전처리

# %%
def Scaler(data_X,method = 'MinMax'):
  X = data_X.copy()
  X = X.astype(np.float64)

  if method == 'Divide255':
    X = X/255.0

  elif method == 'Standard':
    for a in X:
      for i in range(len(['r','g','b'])):
        mean_ = a[:,:,i].mean()
        std_ = a[:,:,i].std()
        a[:,:,i] = (a[:,:,i] - mean_)/std_

  elif method == 'MinMax':
    for a in X:
      for i in range(len(['r','g','b'])):
        max_ = a[:,:,i].max()
        min_ = a[:,:,i].min()
        a[:,:,i] = (a[:,:,i] - min_)/(max_ - min_)

  elif method == 'MinMax255':
    for a in X:
      for i in range(len(['r','g','b'])):
        max_ = a[:,:,i].max()
        min_ = a[:,:,i].min()
        a[:,:,i] = ((a[:,:,i] - min_)/(max_ - min_))*255
    return np.array(X,dtype='uint8')      

  return X

def to_grayscale_then_rgb(image):
    image = tf.image.rgb_to_grayscale(image)
    image = tf.image.grayscale_to_rgb(image)
    return np.array(image)

def img_contrast(img):
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    image_from_array = Image.fromarray(final, 'RGB')
    size_image = image_from_array.resize((height, width))

    return np.array(size_image)

def preprocessing(data_X):
  data = []
  for img in data_X:
    img = img_contrast(to_grayscale_then_rgb(img))
    data.append(img)
  data = np.array(data)

  return data

# %%
X = data
X = preprocessing(Scaler(X, 'MinMax255'))
y = tf.one_hot(labels, num_classes).numpy()

# %%
print(X.shape)
print(y.shape)
# Out:
# (26010, 32, 32, 3)
# (26010, 43)

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# ```python
#
# def add_noise(img):
#     '''Add random noise to an image'''
#     VARIABILITY = 50
#     deviation = VARIABILITY*random.random()
#     noise = np.random.normal(0, deviation, img.shape)
#     img += noise
#     np.clip(img, 0., 255.)
#     return img
#
# # Prepare data-augmenting data generator
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#         rescale=1./255,
#         rotation_range=40,
#         width_shift_range=0.2,
#         height_shift_range=0.2,
#         zoom_range=0.2,
#         preprocessing_function=add_noise,
#     )
# ```

# %%
from sklearn import preprocessing
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.6, 0.9],
    zoom_range=0.2,
    width_shift_range=0.2,    
    height_shift_range=0.2,
    fill_mode='nearest'
)

test_datagen  = ImageDataGenerator(
    rescale=1./255,
)

# %%
idx = 6768
input_img = X[idx]
input_label = y[idx]
input_img =  np.array([input_img]) 

generator = train_datagen.flow(input_img, batch_size=1)

f, axes = plt.subplots(5, 5, figsize=(13, 13))
ax_list = axes.flat
ax_list[0].imshow(input_img[0])
ax_list[0].axis('off')
ax_list[0].set_title("origin")

for i, img in enumerate(generator):
    ax_list[i+1].imshow(img[0])
    ax_list[i+1].axis('off')   
    ax_list[i+1].set_title("augmentation")
    if i > 22:
        break

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11, shuffle=True)

# %%
print("Train Shape: {}\nTest Shape : {}".format(X_train.shape, X_test.shape))
# Out:
# Train Shape: (20808, 32, 32, 3)
# Test Shape : (5202, 32, 32, 3)

# %% [markdown]
# ### 모델 생성

# %%
train_generator = train_datagen.flow(
        X_train, y_train,
        batch_size = 32
) 
validation_generator = test_datagen.flow(
        X_test, y_test,
        batch_size = 32
)

# %%
img_rows, img_cols = 32, 32
img_channels = 3
nb_classes = 43

# %%
resnet = ResNet50(weights= None, include_top=False, input_shape= (img_rows,img_cols,img_channels))

# %%
x = resnet.output
x = GlobalAveragePooling2D()(x) ## flatten 대신
x = Dropout(0.5)(x)
predictions = Dense(nb_classes, activation= 'softmax')(x)
model = Model(inputs = resnet.input, outputs = predictions)

# %%
# model.summary()

# %%
# plot_model(model, show_layer_names=True, show_shapes =True, to_file='model.png', dpi=350)

# %% [markdown]
# ### 모델 학습

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_check = ModelCheckpoint('best_model_v2.h5', monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=0, mode='max', restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.001)
# csv_logger = CSVLogger('train_log.csv', separator=',')

# %%
n_epochs = 50
history =  model.fit(
            train_generator, 
            batch_size = 32, epochs = n_epochs, verbose = 1, 
            validation_data=validation_generator, 
            callbacks = [model_check, early, reduce_lr])
# Out:
# Epoch 1/50
# 651/651 [==============================] - 29s 37ms/step - loss: 4.5458 - accuracy: 0.0858 - val_loss: 359.1852 - val_accuracy: 0.0504 - lr: 0.0010
# Epoch 2/50
# 651/651 [==============================] - 24s 37ms/step - loss: 4.0923 - accuracy: 0.1352 - val_loss: 26.6903 - val_accuracy: 0.0665 - lr: 0.0010
# Epoch 3/50
# 651/651 [==============================] - 25s 38ms/step - loss: 3.5463 - accuracy: 0.1917 - val_loss: 72.4181 - val_accuracy: 0.0894 - lr: 0.0010
# Epoch 4/50
# 651/651 [==============================] - 25s 38ms/step - loss: 3.0607 - accuracy: 0.2769 - val_loss: 2.3653 - val_accuracy: 0.3108 - lr: 0.0010
# Epoch 5/50
# 651/651 [==============================] - 22s 33ms/step - loss: 3.4289 - accuracy: 0.2031 - val_loss: 173.8601 - val_accuracy: 0.0654 - lr: 0.0010
# Epoch 6/50
# 651/651 [==============================] - 21s 32ms/step - loss: 3.0422 - accuracy: 0.2560 - val_loss: 21.7375 - val_accuracy: 0.1894 - lr: 0.0010
# Epoch 7/50
# 651/651 [==============================] - 25s 38ms/step - loss: 2.6876 - accuracy: 0.3379 - val_loss: 1.7139 - val_accuracy: 0.4323 - lr: 0.0010
# Epoch 8/50
# 651/651 [==============================] - 21s 33ms/step - loss: 2.1583 - accuracy: 0.4683 - val_loss: 2.1810 - val_accuracy: 0.3889 - lr: 0.0010
# Epoch 9/50
# 651/651 [==============================] - 21s 33ms/step - loss: 2.6410 - accuracy: 0.3438 - val_loss: 68.8576 - val_accuracy: 0.0085 - lr: 0.0010
# Epoch 10/50
# 651/651 [==============================] - 25s 38ms/step - loss: 2.5437 - accuracy: 0.3471 - val_loss: 1.6908 - val_accuracy: 0.4456 - lr: 0.0010
# Epoch 11/50
# 651/651 [==============================] - 21s 33ms/step - loss: 3.0118 - accuracy: 0.2369 - val_loss: 4.6874 - val_accuracy: 0.1682 - lr: 0.0010
# Epoch 12/50
# 651/651 [==============================] - 21s 32ms/step - loss: 2.4931 - accuracy: 0.3367 - val_loss: 5.0856 - val_accuracy: 0.3378 - lr: 0.0010
# Epoch 13/50
# 651/651 [==============================] - 21s 33ms/step - loss: 2.1814 - accuracy: 0.4109 - val_loss: 2.2474 - val_accuracy: 0.3328 - lr: 0.0010
# Epoch 14/50
# 651/651 [==============================] - 24s 36ms/step - loss: 1.9206 - accuracy: 0.4592 - val_loss: 1.6614 - val_accuracy: 0.4885 - lr: 0.0010
# Epoch 15/50
# 651/651 [==============================] - 21s 32ms/step - loss: 2.5303 - accuracy: 0.3121 - val_loss: 2.0913 - val_accuracy: 0.3499 - lr: 0.0010
# Epoch 16/50
# 651/651 [==============================] - 24s 37ms/step - loss: 1.8130 - accuracy: 0.4708 - val_loss: 1.4948 - val_accuracy: 0.4967 - lr: 0.0010
# Epoch 17/50
# 651/651 [==============================] - 25s 38ms/step - loss: 1.4303 - accuracy: 0.5722 - val_loss: 1.1039 - val_accuracy: 0.6332 - lr: 0.0010
# Epoch 18/50
# 651/651 [==============================] - 24s 37ms/step - loss: 1.3441 - accuracy: 0.6128 - val_loss: 1.0470 - val_accuracy: 0.6515 - lr: 0.0010
# Epoch 19/50
# 651/651 [==============================] - 24s 37ms/step - loss: 1.4365 - accuracy: 0.5871 - val_loss: 0.9361 - val_accuracy: 0.6911 - lr: 0.0010
# Epoch 20/50
# 651/651 [==============================] - 21s 33ms/step - loss: 0.9833 - accuracy: 0.7004 - val_loss: 1.0820 - val_accuracy: 0.6630 - lr: 0.0010
# Epoch 21/50
# 651/651 [==============================] - 24s 36ms/step - loss: 0.8463 - accuracy: 0.7465 - val_loss: 0.7242 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 22/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.8778 - accuracy: 0.7520 - val_loss: 2.5352 - val_accuracy: 0.4379 - lr: 0.0010
# Epoch 23/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.9864 - accuracy: 0.7304 - val_loss: 2.1492 - val_accuracy: 0.3710 - lr: 0.0010
# Epoch 24/50
# 651/651 [==============================] - 24s 36ms/step - loss: 0.6148 - accuracy: 0.8101 - val_loss: 0.5928 - val_accuracy: 0.8245 - lr: 0.0010
# Epoch 25/50
# 651/651 [==============================] - 25s 38ms/step - loss: 0.4604 - accuracy: 0.8577 - val_loss: 0.5373 - val_accuracy: 0.8551 - lr: 0.0010
# Epoch 26/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.5557 - accuracy: 0.8392 - val_loss: 1.2317 - val_accuracy: 0.7953 - lr: 0.0010
# Epoch 27/50
# 651/651 [==============================] - 24s 37ms/step - loss: 0.5178 - accuracy: 0.8518 - val_loss: 0.4234 - val_accuracy: 0.8652 - lr: 0.0010
# Epoch 28/50
# 651/651 [==============================] - 24s 37ms/step - loss: 0.3871 - accuracy: 0.8827 - val_loss: 0.3805 - val_accuracy: 0.8843 - lr: 0.0010
# Epoch 29/50
# 651/651 [==============================] - 24s 37ms/step - loss: 0.4289 - accuracy: 0.8712 - val_loss: 0.2421 - val_accuracy: 0.9227 - lr: 0.0010
# Epoch 30/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.2714 - accuracy: 0.9185 - val_loss: 0.9940 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 31/50
# 651/651 [==============================] - 23s 36ms/step - loss: 0.3614 - accuracy: 0.8942 - val_loss: 0.1824 - val_accuracy: 0.9433 - lr: 0.0010
# Epoch 32/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.3086 - accuracy: 0.9092 - val_loss: 0.1824 - val_accuracy: 0.9408 - lr: 0.0010
# Epoch 33/50
# 651/651 [==============================] - 24s 37ms/step - loss: 0.2305 - accuracy: 0.9310 - val_loss: 0.1505 - val_accuracy: 0.9514 - lr: 0.0010
# Epoch 34/50
# 651/651 [==============================] - 22s 34ms/step - loss: 0.1999 - accuracy: 0.9399 - val_loss: 0.1599 - val_accuracy: 0.9469 - lr: 0.0010
# Epoch 35/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.3065 - accuracy: 0.9135 - val_loss: 0.3406 - val_accuracy: 0.9168 - lr: 0.0010
# Epoch 36/50
# 651/651 [==============================] - 20s 31ms/step - loss: 0.2317 - accuracy: 0.9322 - val_loss: 0.1707 - val_accuracy: 0.9452 - lr: 0.0010
# Epoch 37/50
# 651/651 [==============================] - 20s 31ms/step - loss: 0.1691 - accuracy: 0.9469 - val_loss: 0.2945 - val_accuracy: 0.9146 - lr: 0.0010
# Epoch 38/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.1595 - accuracy: 0.9510 - val_loss: 0.2146 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 39/50
# 651/651 [==============================] - 22s 34ms/step - loss: 0.3456 - accuracy: 0.9108 - val_loss: 2.6977 - val_accuracy: 0.6669 - lr: 0.0010
# Epoch 40/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.2775 - accuracy: 0.9195 - val_loss: 1.3901 - val_accuracy: 0.8379 - lr: 0.0010
# Epoch 41/50
# 651/651 [==============================] - 24s 37ms/step - loss: 0.1631 - accuracy: 0.9511 - val_loss: 0.1502 - val_accuracy: 0.9579 - lr: 0.0010
# Epoch 42/50
# 651/651 [==============================] - 25s 38ms/step - loss: 0.1265 - accuracy: 0.9608 - val_loss: 0.1196 - val_accuracy: 0.9614 - lr: 0.0010
# Epoch 43/50
# 651/651 [==============================] - 22s 33ms/step - loss: 0.3045 - accuracy: 0.9210 - val_loss: 0.2300 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 44/50
# 651/651 [==============================] - 21s 32ms/step - loss: 0.2669 - accuracy: 0.9228 - val_loss: 2.9648 - val_accuracy: 0.8962 - lr: 0.0010
# Epoch 45/50
# 651/651 [==============================] - 24s 36ms/step - loss: 0.1518 - accuracy: 0.9567 - val_loss: 0.1291 - val_accuracy: 0.9606 - lr: 0.0010
# Epoch 46/50
# 651/651 [==============================] - 26s 40ms/step - loss: 0.1192 - accuracy: 0.9645 - val_loss: 0.1026 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 47/50
# 651/651 [==============================] - 23s 35ms/step - loss: 0.1728 - accuracy: 0.9530 - val_loss: 0.2644 - val_accuracy: 0.9166 - lr: 0.0010
# Epoch 48/50
# 651/651 [==============================] - 22s 34ms/step - loss: 0.2967 - accuracy: 0.9262 - val_loss: 0.2601 - val_accuracy: 0.9179 - lr: 0.0010
# Epoch 49/50
# 651/651 [==============================] - 23s 35ms/step - loss: 0.2053 - accuracy: 0.9395 - val_loss: 0.3495 - val_accuracy: 0.9423 - lr: 0.0010
# Epoch 50/50
# 651/651 [==============================] - 26s 40ms/step - loss: 0.1314 - accuracy: 0.9609 - val_loss: 0.0640 - val_accuracy: 0.9802 - lr: 0.0010

# %%
model_name = "model_resnet_augmentation_contrast_v2.h5"

# %%
model.save(model_name)

# %% [markdown]
# ### 모델 평가

# %%
from tensorflow import keras 
best_model = keras.models.load_model("best_model_v2.h5")

# %%
valid_datagen = ImageDataGenerator(rescale=1./255)
valid_generator = valid_datagen.flow(
        X_test, y_test,
        batch_size = 32,
        shuffle=False
)

# %%
loss, acc = model.evaluate_generator(valid_generator)
print('Accuracy: ', acc, '\nLoss    : ', loss)
# Out:
# Accuracy:  0.980199933052063
# Loss    :  0.06399103254079819

# %%
loss, acc = best_model.evaluate_generator(valid_generator)
print('Accuracy: ', acc, '\nLoss    : ', loss)
# Out:
# Accuracy:  0.980199933052063
# Loss    :  0.06399103254079819

# %%
from sklearn.metrics import classification_report, confusion_matrix

valid_generator.reset()
y_pred = model.predict_generator(valid_generator)
y_pred = tf.argmax(y_pred, axis=1).numpy()

# %%
print(classification_report(np.argmax(y_test, axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        26
#            1       0.97      0.98      0.98       255
#            2       1.00      0.95      0.98       273
#            3       0.98      1.00      0.99       255
#            4       1.00      0.98      0.99       263
#            5       0.96      0.98      0.97       249
#            6       1.00      0.97      0.99        35
#            7       0.97      0.96      0.97       231
#            8       0.95      0.99      0.97       212
#            9       1.00      1.00      1.00       236
#           10       1.00      0.99      0.99       250
#           11       1.00      0.98      0.99       247
#           12       0.98      0.99      0.99       254
#           13       0.99      1.00      0.99       254
#           14       0.99      0.99      0.99       151
#           15       0.99      0.97      0.98       118
#           16       1.00      1.00      1.00        40
#           17       1.00      0.99      1.00       147
#           18       0.99      0.98      0.98       133
#           19       0.94      0.97      0.96        35
#           20       0.95      0.97      0.96        37
#           21       0.83      1.00      0.91        35
#           22       1.00      1.00      1.00        30
#           23       0.97      0.81      0.88        37
#           24       1.00      0.98      0.99        41
#           25       0.99      0.98      0.99       257
#           26       0.93      0.93      0.93        27
#           27       0.98      1.00      0.99        41
#           28       0.97      1.00      0.98        31
#           29       1.00      0.95      0.97        37
#           30       0.89      1.00      0.94        32
#           31       0.99      1.00      1.00       124
#           32       1.00      0.82      0.90        38
#           33       0.99      1.00      1.00       124
#           34       0.95      0.82      0.88        45
#           35       1.00      0.96      0.98       131
#           36       0.95      0.95      0.95        37
#           37       1.00      1.00      1.00        32
#           38       0.96      1.00      0.98       257
#           39       1.00      1.00      1.00        33
#           40       0.87      1.00      0.93        41
#           41       0.86      0.97      0.91        37
#           42       1.00      0.97      0.99        34
#
#     accuracy                           0.98      5202
#    macro avg       0.97      0.97      0.97      5202
# weighted avg       0.98      0.98      0.98      5202

# %%
print(confusion_matrix(np.argmax(y_test, axis=1), y_pred, labels=range(9)))
# Out:
# [[ 26   0   0   0   0   0   0   0   0]
#  [  0 251   0   0   0   1   0   2   0]
#  [  0   4 260   1   0   4   0   1   0]
#  [  0   0   0 254   0   1   0   0   0]
#  [  3   2   0   0 257   0   0   0   1]
#  [  0   0   0   2   0 243   0   2   1]
#  [  0   0   0   1   0   0  34   0   0]
#  [  0   0   0   0   0   2   0 221   8]
#  [  1   0   0   0   0   0   0   0 210]]

# %%
# q = len(list(history.history['loss']))
# plt.figure(figsize=(12, 6))
# sns.lineplot(x = range(1, 1+q), y = history.history['accuracy'], label = 'Accuracy')
# sns.lineplot(x = range(1, 1+q), y = history.history['loss'], label = 'Loss')
# plt.xlabel('#epochs')
# plt.ylabel('Training')
# plt.legend();

# %% [markdown]
# ### 모델 테스트

# %%
from tensorflow import keras 
model = keras.models.load_model(model_name)

# %% [markdown]
# ### 테스트 데이터 예측

# %%
# test_data = []
# file_name = []
# path = f'./data/Test/'
# Class = os.listdir(path)
# for a in Class:
#     image = cv2.imread(path + a)
#     image = img_contrast(image)
#     image_from_array = Image.fromarray(image, 'RGB')
#     size_image = image_from_array.resize((height, width))
#     test_data.append(np.array(size_image))
#     file_name.append(a)

# test_data = np.array(test_data)
# file_name = np.array(file_name)

# import pickle 

# with open('./data/test_data_contrast.pkl', 'wb') as f:
#     pickle.dump(test_data, f)

# with open('./data/file_name_contrast.pkl', 'wb') as f:
#     pickle.dump(file_name, f)

# %%
with open('./data/test_data_contrast.pkl', 'rb') as f:
    test_data = pickle.load(f)

with open('./data/file_name_contrast.pkl', 'rb') as f:
    file_name = pickle.load(f)

# %%
test_data_origin = test_data

# %%
test_data = preprocessing(Scaler(test_data, 'MinMax255'))
test_data.shape
# Out:
# (8670, 32, 32, 3)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow(
        test_data,
        batch_size = 32,
        shuffle=False
)

# %%
test_generator.reset()
test_label = model.predict_generator(test_generator)
test_label = tf.argmax(test_label, axis=1).numpy()

# %%
def show_label_image(data, label, file_name, category):
    fig, axes = plt.subplots(nrows = 10, ncols = 10, figsize=(18, 18))
    img_filter = np.argwhere(label==category).reshape(-1)
    img = data[img_filter]
    name = file_name[img_filter]
    index = np.random.choice(list(range(len(img))), 100)
    for i, ax in enumerate(axes.flat):
        r = index[i]
        ax.imshow(img[r])
        ax.set_title(name[r], fontsize=10)
        ax.set_xticks([])
        ax.set_yticks([])
    plt.tight_layout()
    plt.show()

# %%
show_label_image(test_data_origin, test_label, file_name, 4)

# %%
f, ax = plt.subplots(figsize=(10, 5))
sns.countplot(test_label)

# %%
csv_data = pd.DataFrame(np.concatenate((file_name.reshape(-1, 1), test_label.reshape(-1,1)), axis=1))

# %%
csv_data = csv_data.sort_values(by=[0])
csv_data.head()
# Out:
#               0   1
# 279   00000.png  16
# 8119  00001.png   1
# 3628  00002.png  38
# 1565  00003.png  33
# 5360  00004.png  11

# %%
csv_data.to_csv("predicted_output_v2.csv", header=False, index=False)

# %%
from google.colab import files
files.download("predicted_output_v2.csv")

# %% [markdown]
# ### 주석
