# %% [markdown]
# <a href="https://colab.research.google.com/github/sh3986/kaggle/blob/main/v2_keras_resnet_origin_contrast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Library

# %%
import numpy as np 
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
pd.options.display.float_format = "{:.5f}".format

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import Pipeline

import os
from os import listdir
from os.path import isfile, join
import cv2
from PIL import Image
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras import optimizers
tf.__version__
# Out:
# '2.8.2'

# %%
# Visualization
from tensorflow.keras.utils import plot_model

# Splitting data
from sklearn.model_selection import train_test_split

# Metrics 
from sklearn.metrics import confusion_matrix, classification_report

# Deep Learning
import tensorflow as tf
print('TensoFlow Version: ', tf.__version__)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications.resnet import ResNet50

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger

import skimage.morphology as morp
from skimage.filters import rank
# Out:
# TensoFlow Version:  2.8.2

# %%
data_path = "/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn"

# %%
import os
os.chdir(data_path)

# %%
data = []
labels = []

height = 32
width = 32
channels = 3
num_classes = 43

# %%
def img_contrast(img):
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    return final

# %%
# for i in range(num_classes) :
#     path = f'./data/Train/{i}/'
#     Class = os.listdir(path)
#     for a in Class:
#         image = cv2.imread(path + a)
#         image_from_array = Image.fromarray(image, 'RGB')
#         size_image = image_from_array.resize((height, width))
#         data.append(np.array(size_image))
#         labels.append(i)
        
#         image = img_contrast(image)
#         image_from_array = Image.fromarray(image, 'RGB')
#         size_image = image_from_array.resize((height, width))
#         data.append(np.array(size_image))
#         labels.append(i)

# data = np.array(data)
# labels = np.array(labels)

# import pickle
# with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_data_with_contrast.pkl","wb") as f:
#     pickle.dump(data, f)

# with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_label_with_contrast.pkl","wb") as f:
#     pickle.dump(labels, f)

# %%
import pickle
with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_data_with_contrast.pkl","rb") as f:
    data = pickle.load(f)

import pickle
with open("/content/drive/MyDrive/Colab Notebooks/Kaggle/project_2_cnn/data/train_label_with_contrast.pkl","rb") as f:
    labels = pickle.load(f)

# %%
print(data.shape)
print(labels.shape)
# Out:
# (52020, 32, 32, 3)
# (52020,)

# %% [markdown]
# ### 데이터 로드

# %%
X = data
y = tf.one_hot(labels, num_classes).numpy()

# %%
print(X.shape)
print(y.shape)
# Out:
# (52020, 32, 32, 3)
# (52020, 43)

# %% [markdown]
# ### 탐색 분석

# %%
fig, axes = plt.subplots(10,10, figsize=(18,18))
for i,ax in enumerate(axes.flat):
    r = np.random.randint(X.shape[0])
    ax.imshow(X[r].astype('uint8'))
    ax.grid(False)
    ax.axis('off')
    ax.set_title('Label: '+str(np.argmax(y[r]))+" "+str(r))

# %%
f, ax = plt.subplots(figsize=(10, 5))
sns.countplot(labels)

# %%
uni_pattern = np.unique(labels, return_counts=True)
idxs = uni_pattern[0]
ratios = uni_pattern[1]/len(labels)

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# ```python
#
# def add_noise(img):
#     '''Add random noise to an image'''
#     VARIABILITY = 50
#     deviation = VARIABILITY*random.random()
#     noise = np.random.normal(0, deviation, img.shape)
#     img += noise
#     np.clip(img, 0., 255.)
#     return img
#
# # Prepare data-augmenting data generator
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#         rescale=1./255,
#         rotation_range=40,
#         width_shift_range=0.2,
#         height_shift_range=0.2,
#         zoom_range=0.2,
#         preprocessing_function=add_noise,
#     )
# ```

# %%
from sklearn import preprocessing
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        brightness_range=[0.6, 0.9],
        zoom_range=0.2,
        width_shift_range=0.2,
        height_shift_range=0.2,
        fill_mode='nearest'
)

test_datagen  = ImageDataGenerator(
    rescale=1./255,
)

# %%
idx = 6768
input_img = X[idx]
input_label = y[idx]
input_img =  np.array([input_img]) 

generator = train_datagen.flow(input_img, batch_size=1)

f, axes = plt.subplots(5, 5, figsize=(13, 13))
ax_list = axes.flat
ax_list[0].imshow(input_img[0])
ax_list[0].axis('off')
ax_list[0].set_title("origin")

for i, img in enumerate(generator):
    ax_list[i+1].imshow(img[0])
    ax_list[i+1].axis('off')   
    ax_list[i+1].set_title("augmentation")
    if i > 22:
        break

# %% [markdown]
# ### 전처리

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %%
print("Train Shape: {}\nTest Shape : {}".format(X_train.shape, X_test.shape))
# Out:
# Train Shape: (41616, 32, 32, 3)
# Test Shape : (10404, 32, 32, 3)

# %% [markdown]
# ### 모델 생성

# %%
train_generator = train_datagen.flow(
        X_train, y_train,
        batch_size = 32
) 

validation_generator = test_datagen.flow(
        X_test, y_test,
        batch_size = 32
)

# %%
img_rows, img_cols = 32, 32
img_channels = 3
nb_classes = 43

# %%
resnet = ResNet50(weights= None, include_top=False, input_shape= (img_rows,img_cols,img_channels))

# %%
x = resnet.output
x = GlobalAveragePooling2D()(x) ## flatten 대신
x = Dropout(0.5)(x)
predictions = Dense(nb_classes, activation= 'softmax')(x)
model = Model(inputs = resnet.input, outputs = predictions)

# %%
# model.summary()

# %%
# plot_model(model, show_layer_names=True, show_shapes =True, to_file='model.png', dpi=350)

# %% [markdown]
# ### 모델 학습

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_check = ModelCheckpoint('best_model_v2.h5', monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=0, mode='max', restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.001)
# csv_logger = CSVLogger('train_log.csv', separator=',')

# %%
n_epochs = 50
history =  model.fit(
            train_generator, 
            batch_size = 32, epochs = n_epochs, verbose = 1, 
            validation_data=validation_generator, 
            callbacks = [model_check, early, reduce_lr])
# Out:
# Epoch 1/50
# 1301/1301 [==============================] - 62s 48ms/step - loss: 4.4023 - accuracy: 0.0900 - val_loss: 18.9940 - val_accuracy: 0.0739 - lr: 0.0010
# Epoch 2/50
# 1301/1301 [==============================] - 62s 48ms/step - loss: 3.6456 - accuracy: 0.1569 - val_loss: 15.8495 - val_accuracy: 0.1968 - lr: 0.0010
# Epoch 3/50
# 1301/1301 [==============================] - 59s 45ms/step - loss: 3.5803 - accuracy: 0.1573 - val_loss: 19.7155 - val_accuracy: 0.0679 - lr: 0.0010
# Epoch 4/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 3.7357 - accuracy: 0.1002 - val_loss: 3.1697 - val_accuracy: 0.1136 - lr: 0.0010
# Epoch 5/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 3.5278 - accuracy: 0.1206 - val_loss: 3.3623 - val_accuracy: 0.1305 - lr: 0.0010
# Epoch 6/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 3.1051 - accuracy: 0.1843 - val_loss: 6.7468 - val_accuracy: 0.2222 - lr: 0.0010
# Epoch 7/50
# 1301/1301 [==============================] - 59s 45ms/step - loss: 2.8537 - accuracy: 0.2203 - val_loss: 26.6945 - val_accuracy: 0.2215 - lr: 0.0010
# Epoch 8/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 2.2864 - accuracy: 0.3330 - val_loss: 27.4279 - val_accuracy: 0.1758 - lr: 0.0010
# Epoch 9/50
# 1301/1301 [==============================] - 62s 47ms/step - loss: 1.8200 - accuracy: 0.4420 - val_loss: 1.9001 - val_accuracy: 0.4434 - lr: 0.0010
# Epoch 10/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 1.5219 - accuracy: 0.5297 - val_loss: 3.3303 - val_accuracy: 0.4070 - lr: 0.0010
# Epoch 11/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 1.2618 - accuracy: 0.6038 - val_loss: 1.3021 - val_accuracy: 0.5794 - lr: 0.0010
# Epoch 12/50
# 1301/1301 [==============================] - 62s 48ms/step - loss: 1.1509 - accuracy: 0.6378 - val_loss: 2.3313 - val_accuracy: 0.7254 - lr: 0.0010
# Epoch 13/50
# 1301/1301 [==============================] - 62s 47ms/step - loss: 0.7961 - accuracy: 0.7350 - val_loss: 0.8128 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 14/50
# 1301/1301 [==============================] - 62s 47ms/step - loss: 0.6935 - accuracy: 0.7741 - val_loss: 6.4358 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 15/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.6325 - accuracy: 0.7983 - val_loss: 144.7084 - val_accuracy: 0.1442 - lr: 0.0010
# Epoch 16/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.5628 - accuracy: 0.8168 - val_loss: 1.3614 - val_accuracy: 0.6504 - lr: 0.0010
# Epoch 17/50
# 1301/1301 [==============================] - 62s 47ms/step - loss: 0.6348 - accuracy: 0.7981 - val_loss: 0.9046 - val_accuracy: 0.8695 - lr: 0.0010
# Epoch 18/50
# 1301/1301 [==============================] - 59s 45ms/step - loss: 0.9443 - accuracy: 0.7121 - val_loss: 1.7566 - val_accuracy: 0.7487 - lr: 0.0010
# Epoch 19/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.4908 - accuracy: 0.8415 - val_loss: 18.8048 - val_accuracy: 0.8349 - lr: 0.0010
# Epoch 20/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.4084 - accuracy: 0.8693 - val_loss: 8.4583 - val_accuracy: 0.8536 - lr: 0.0010
# Epoch 21/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.9077 - accuracy: 0.7348 - val_loss: 1.7368 - val_accuracy: 0.4837 - lr: 0.0010
# Epoch 22/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.7227 - accuracy: 0.7736 - val_loss: 1.2660 - val_accuracy: 0.7760 - lr: 0.0010
# Epoch 23/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 0.3607 - accuracy: 0.8838 - val_loss: 0.3833 - val_accuracy: 0.8814 - lr: 0.0010
# Epoch 24/50
# 1301/1301 [==============================] - 62s 48ms/step - loss: 0.3348 - accuracy: 0.8946 - val_loss: 0.3090 - val_accuracy: 0.9003 - lr: 0.0010
# Epoch 25/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.3655 - accuracy: 0.8834 - val_loss: 0.7698 - val_accuracy: 0.7559 - lr: 0.0010
# Epoch 26/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 0.2674 - accuracy: 0.9142 - val_loss: 0.2608 - val_accuracy: 0.9251 - lr: 0.0010
# Epoch 27/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.2215 - accuracy: 0.9296 - val_loss: 0.2635 - val_accuracy: 0.9234 - lr: 0.0010
# Epoch 28/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 0.2003 - accuracy: 0.9369 - val_loss: 0.2310 - val_accuracy: 0.9296 - lr: 0.0010
# Epoch 29/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.2061 - accuracy: 0.9362 - val_loss: 0.3619 - val_accuracy: 0.9213 - lr: 0.0010
# Epoch 30/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 0.2289 - accuracy: 0.9285 - val_loss: 0.1990 - val_accuracy: 0.9409 - lr: 0.0010
# Epoch 31/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.1398 - accuracy: 0.9569 - val_loss: 0.3916 - val_accuracy: 0.8824 - lr: 0.0010
# Epoch 32/50
# 1301/1301 [==============================] - 57s 44ms/step - loss: 0.1702 - accuracy: 0.9487 - val_loss: 0.3092 - val_accuracy: 0.9217 - lr: 0.0010
# Epoch 33/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.2360 - accuracy: 0.9314 - val_loss: 0.3985 - val_accuracy: 0.9345 - lr: 0.0010
# Epoch 34/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.1778 - accuracy: 0.9468 - val_loss: 0.2042 - val_accuracy: 0.9381 - lr: 0.0010
# Epoch 35/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 0.1264 - accuracy: 0.9616 - val_loss: 0.1450 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 36/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.2061 - accuracy: 0.9385 - val_loss: 0.2196 - val_accuracy: 0.9309 - lr: 0.0010
# Epoch 37/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.1106 - accuracy: 0.9653 - val_loss: 0.3861 - val_accuracy: 0.9398 - lr: 0.0010
# Epoch 38/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.1117 - accuracy: 0.9663 - val_loss: 0.3198 - val_accuracy: 0.9398 - lr: 0.0010
# Epoch 39/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.1433 - accuracy: 0.9574 - val_loss: 0.4466 - val_accuracy: 0.9123 - lr: 0.0010
# Epoch 40/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 0.1118 - accuracy: 0.9661 - val_loss: 0.1707 - val_accuracy: 0.9613 - lr: 0.0010
# Epoch 41/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.1392 - accuracy: 0.9627 - val_loss: 1.4003 - val_accuracy: 0.7708 - lr: 0.0010
# Epoch 42/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.1366 - accuracy: 0.9587 - val_loss: 0.1591 - val_accuracy: 0.9591 - lr: 0.0010
# Epoch 43/50
# 1301/1301 [==============================] - 61s 47ms/step - loss: 0.0902 - accuracy: 0.9718 - val_loss: 0.1278 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 44/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.0907 - accuracy: 0.9735 - val_loss: 0.3654 - val_accuracy: 0.9092 - lr: 0.0010
# Epoch 45/50
# 1301/1301 [==============================] - 58s 44ms/step - loss: 0.0803 - accuracy: 0.9753 - val_loss: 0.1814 - val_accuracy: 0.9510 - lr: 0.0010
# Epoch 46/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.1474 - accuracy: 0.9577 - val_loss: 0.2709 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 47/50
# 1301/1301 [==============================] - 62s 47ms/step - loss: 0.1924 - accuracy: 0.9441 - val_loss: 0.1033 - val_accuracy: 0.9699 - lr: 0.0010
# Epoch 48/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.0806 - accuracy: 0.9759 - val_loss: 0.1643 - val_accuracy: 0.9570 - lr: 0.0010
# Epoch 49/50
# 1301/1301 [==============================] - 58s 45ms/step - loss: 0.0742 - accuracy: 0.9784 - val_loss: 0.1176 - val_accuracy: 0.9681 - lr: 0.0010
# Epoch 50/50
# 1301/1301 [==============================] - 59s 45ms/step - loss: 0.1269 - accuracy: 0.9650 - val_loss: 0.1168 - val_accuracy: 0.9674 - lr: 0.0010

# %%
model_name = "model_resnet_augmentation_contrast_v2.h5"

# %%
model.save(model_name)

# %% [markdown]
# ### 모델 평가

# %%
from tensorflow import keras 
best_model = keras.models.load_model("best_model_v2.h5")

# %%
loss, acc = model.evaluate(X_test/255.0, y_test)
print('Accuracy: ', acc, '\nLoss    : ', loss)
# Out:
# 326/326 [==============================] - 6s 16ms/step - loss: 0.1168 - accuracy: 0.9674
# Accuracy:  0.9674164056777954
# Loss    :  0.11683999001979828

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test/255.0)
y_pred = tf.argmax(y_pred, axis=1).numpy()

# %%
print(classification_report(np.argmax(y_test, axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        71
#            1       0.97      0.98      0.97       515
#            2       0.93      0.96      0.94       478
#            3       0.96      0.98      0.97       533
#            4       0.99      0.95      0.97       550
#            5       0.89      0.97      0.93       533
#            6       0.93      0.92      0.92        60
#            7       0.97      0.90      0.93       483
#            8       0.96      0.96      0.96       541
#            9       0.98      0.97      0.98       511
#           10       0.99      1.00      0.99       502
#           11       0.97      1.00      0.98       474
#           12       1.00      0.99      1.00       466
#           13       0.95      1.00      0.97       492
#           14       1.00      0.99      0.99       245
#           15       1.00      0.96      0.98       256
#           16       0.99      0.92      0.95        75
#           17       1.00      0.98      0.99       242
#           18       0.99      0.92      0.95       243
#           19       0.97      0.88      0.92        74
#           20       0.98      0.82      0.89        65
#           21       0.96      1.00      0.98        68
#           22       0.98      1.00      0.99        80
#           23       0.89      0.96      0.92        67
#           24       0.99      1.00      0.99        69
#           25       0.95      0.99      0.97       507
#           26       0.99      0.85      0.91        84
#           27       1.00      1.00      1.00        92
#           28       0.99      0.99      0.99        78
#           29       1.00      0.96      0.98        78
#           30       0.82      0.94      0.88        68
#           31       1.00      0.97      0.98       231
#           32       0.93      1.00      0.96        68
#           33       1.00      0.98      0.99       240
#           34       1.00      0.96      0.98        69
#           35       0.98      0.99      0.99       250
#           36       1.00      0.85      0.92        74
#           37       1.00      1.00      1.00        82
#           38       0.97      0.97      0.97       501
#           39       1.00      1.00      1.00        82
#           40       0.99      0.90      0.94        77
#           41       0.97      0.92      0.94        65
#           42       0.94      0.97      0.95        65
#
#     accuracy                           0.97     10404
#    macro avg       0.97      0.96      0.96     10404
# weighted avg       0.97      0.97      0.97     10404

# %%
print(confusion_matrix(np.argmax(y_test, axis=1), y_pred, labels=range(9)))
# Out:
# [[ 68   2   0   0   0   0   0   1   0]
#  [  0 504   2   0   0   4   0   4   1]
#  [  0   1 458   4   0   7   0   2   1]
#  [  0   0   0 522   0  11   0   0   0]
#  [  2  11   6   0 523   2   0   3   3]
#  [  0   1   1   9   0 518   1   1   0]
#  [  0   0   0   0   0   4  55   0   0]
#  [  0   1   2   0   0  27   0 435  16]
#  [  0   0  16   0   0   4   0   1 519]]

# %%
# q = len(list(history.history['loss']))
# plt.figure(figsize=(12, 6))
# sns.lineplot(x = range(1, 1+q), y = history.history['accuracy'], label = 'Accuracy')
# sns.lineplot(x = range(1, 1+q), y = history.history['loss'], label = 'Loss')
# plt.xlabel('#epochs')
# plt.ylabel('Training')
# plt.legend();

# %% [markdown]
# ### 모델 테스트

# %%
from tensorflow import keras 
model = keras.models.load_model(model_name)

# %% [markdown]
# ### 테스트 데이터 예측

# %%
# test_data = []
# file_name = []
# path = f'./data/Test/'
# Class = os.listdir(path)
# for a in Class:
#     image = cv2.imread(path + a)
#     image = img_contrast(image)
#     image_from_array = Image.fromarray(image, 'RGB')
#     size_image = image_from_array.resize((height, width))
#     test_data.append(np.array(size_image))
#     file_name.append(a)

# test_data = np.array(test_data)
# file_name = np.array(file_name)

# import pickle 

# with open('./data/test_data_contrast.pkl', 'wb') as f:
#     pickle.dump(test_data, f)

# with open('./data/file_name_contrast.pkl', 'wb') as f:
#     pickle.dump(file_name, f)

# %%
with open('./data/test_data_contrast.pkl', 'rb') as f:
    test_data = pickle.load(f)

with open('./data/file_name_contrast.pkl', 'rb') as f:
    file_name = pickle.load(f)

# %%
test_data.shape
# Out:
# (8670, 32, 32, 3)

# %%
y_test = model.predict(test_data/255.0)
y_test = tf.argmax(y_test, axis=1).numpy()

# %%
def show_label_image(data, label, file_name, category):
    fig, axes = plt.subplots(nrows = 10, ncols = 10, figsize=(18, 18))
    img_filter = np.argwhere(label==category).reshape(-1)
    img = data[img_filter]
    name = file_name[img_filter]
    index = np.random.choice(list(range(len(img))), 100)
    for i, ax in enumerate(axes.flat):
        r = index[i]
        ax.imshow(img[r])
        ax.set_title(name[r], fontsize=10)
        ax.set_xticks([])
        ax.set_yticks([])
    plt.tight_layout()
    plt.show()

# %%
show_label_image(test_data, y_test, file_name, 5)

# %%
f, ax = plt.subplots(figsize=(10, 5))
sns.countplot(y_test)

# %%
csv_data = pd.DataFrame(np.concatenate((file_name.reshape(-1, 1), y_test.reshape(-1,1)), axis=1))

# %%
csv_data = csv_data.sort_values(by=[0])
csv_data.head()
# Out:
#               0   1
# 279   00000.png  16
# 8119  00001.png   1
# 3628  00002.png  38
# 1565  00003.png  35
# 5360  00004.png  11

# %%
csv_data.to_csv("predicted_output_v2.csv", header=False, index=False)

# %% [markdown]
# ### 주석
